# %%
# !pip install pywebio
# Out:
# ...
#   Created wheel for pywebio: filename=pywebio-1.2.3-py3-none-any.whl size=322621 sha256=812b3be81fd6f5c84d0f90075eb570bd2a91567e67af10340c79b9bba4f5848c
#   Stored in directory: c:\users\kiit\appdata\local\pip\cache\wheels\9d\34\25\d87104365b5f9ff21cea843fd1385ece5bd16672f9857c43a1
# Successfully built pywebio
# ...

# %%
from pywebio.input import * #bring up a text box
from pywebio.output import *

# %%
#Input
password = input("Enter the password", Type= PASSWORD)
gift = select("which gift you want?",['phone','ipad',"laptop",'fine dinner']) #dropdown
agree = checkbox("user term", options= ['A','B','C','D']) #single select option
text = textarea("Text area", rows= 3, placeholder = 'some message') #multiple line input
img= file_upload("select an image:", accept='image/*') #file upload

answer= radio("choose one",options=['A','B','C','D'])
put_text(answer)

# %%
answer
# Out:
# 'C'

# %%
img
# Out:
# {'filename': 'zoom1.jpg',
#  'size': 49790,
#  'mime_type': 'image/jpeg',
#  'last_modified': 1596979830.71,
#  'dataurl': 'data:image/jpeg;base64,...',
# ...

# %%
password
# Out:
# 'monisha'

# %%
def check_age(p):
    if p < 10:
        return "Too Young!!"
    if p > 60:
        return "Too old!!"
age= input('How old are you?', type=NUMBER, validate= check_age)

# %%
age
# Out:
# 26
