# %%
# Pandas is an open source, BSD-licensed libarary providing high performance, easy-to-use data structure and data analysis tools for the python programming lang.
#dataframe- more than one row and more than one column
#series only a single row.

# %%
#import
import numpy as np
import pandas as pd

# %%
df=pd.DataFrame(np.arange(0,20).reshape(5,4),index=['R1','R2','R3','R4','R5'],columns=['C1','C2','C3','C4'])

# %%
df.head()
# Out:
#     C1  C2  C3  C4
# R1   0   1   2   3
# R2   4   5   6   7
# R3   8   9  10  11
# R4  12  13  14  15
# R5  16  17  18  19

# %%
data=pd.DataFrame(np.random.randint(0,100,20).reshape(5,4),index=['R1','R2','R3','R4','R5'],columns=['C1','C2','C3','C4'])

# %%
data
# Out:
#     C1  C2  C3  C4
# R1  79  29  46  72
# R2  86  84  66  52
# R3  84  37  32  66
# R4  58  91  50  52
# R5  99  69   5  42

# %%
data.to_csv("Test.csv") #to convert to csv document.

# %%
#Accessing the elements
#1.Loc 2. iloc
data.loc['R1'] #retriving the only row1 which is a series
# Out:
# C1    79
# C2    29
# C3    46
# C4    72
# Name: R1, dtype: int32

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.loc['R2'])
# Out:
# pandas.core.series.Series

# %%
data.iloc[:,:]
# Out:
#     C1  C2  C3  C4
# R1  79  29  46  72
# R2  86  84  66  52
# R3  84  37  32  66
# R4  58  91  50  52
# R5  99  69   5  42

# %%
data.iloc[0:2,0:3]
# Out:
#     C1  C2  C3
# R1  79  29  46
# R2  86  84  66

# %%
type(data.iloc[:,:-1])
# Out:
# pandas.core.frame.DataFrame

# %%
#dataframe can be converted to arrary
data.iloc[:,1:].values
# Out:
# array([[29, 46, 72],
#        [84, 66, 52],
#        [37, 32, 66],
#        [91, 50, 52],
#        [69,  5, 42]])

# %%
#check null condition
data.isnull().sum()
# Out:
# C1    0
# C2    0
# C3    0
# C4    0
# dtype: int64

# %%
data["C1"].value_counts()
# Out:
# 79    1
# 86    1
# 84    1
# 99    1
# 58    1
# Name: C1, dtype: int64

# %%
data["C2"].unique()
# Out:
# array([29, 84, 37, 91, 69])

# %%
data[["C1","C2"]] #retriving more than one columns.
# Out:
#     C1  C2
# R1  79  29
# R2  86  84
# R3  84  37
# R4  58  91
# R5  99  69

# %%
#read Json(is basically keyvalue:data) to Csv
data1='{"employee_name":"James","email":"james@gmail.com","job_profile":[{"tittle1":"team lead","title2":"leader"}],"employee_name":"James","email":"james@gmail.com","job_profile":[{"tittle1":"team lead","title2":"leader"}],"employee_name":"James","email":"james@gmail.com","job_profile":[{"tittle1":"team lead","title2":"leader"}],"employee_name":"moni","email":"moni@gmail.com","job_profile":[{"tittle1":"team lead","title2":"leader"}]}'
df1=pd.read_json(data1)

# %%
df1.to_json()
# Out:
# '{"employee_name":{"0":"moni"},"email":{"0":"moni@gmail.com"},"job_profile":{"0":{"tittle1":"team lead","title2":"leader"}}}'

# %%
df1
# Out:
#   employee_name           email                                   job_profile
# 0          moni  moni@gmail.com  {'tittle1': 'team lead', 'title2': 'leader'}

# %%
df1.to_json(orient="records")
# Out:
# '[{"employee_name":"moni","email":"moni@gmail.com","job_profile":{"tittle1":"team lead","title2":"leader"}}]'

# %%
df1.to_json(orient='split')
# Out:
# '{"columns":["employee_name","email","job_profile"],"index":[0],"data":[["moni","moni@gmail.com",{"tittle1":"team lead","title2":"leader"}]]}'

# %%
#Reading HTMLpage
url='https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/'
dfs=pd.read_html(url)

# %%
dfs[0]
# Out:
#                              Bank Name               City State   Cert  \
# 0                    Almena State Bank             Almena    KS  15426
# 1           First City Bank of Florida  Fort Walton Beach    FL  16748
# 2                 The First State Bank      Barboursville    WV  14361
# 3                   Ericson State Bank            Ericson    NE  18265
# 4     City National Bank of New Jersey             Newark    NJ  21111
# ..                                 ...                ...   ...    ...
# 558                 Superior Bank, FSB           Hinsdale    IL  32646
# 559                Malta National Bank              Malta    OH   6629
# 560    First Alliance Bank & Trust Co.         Manchester    NH  34264
# 561  National State Bank of Metropolis         Metropolis    IL   3815
# 562                   Bank of Honolulu           Honolulu    HI  21029
#
#                    Acquiring Institution       Closing Date
# ...

# %%
type(dfs)
# Out:
# list

# %%
#read excel file
#pd.read_excel("sheet name")
df=pd.read_csv("C://Users//KIIT//Documents//python practise//Day1//winequality-red.csv",usecols=["fixed acidity","volatile acidity","citric acid"])

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid
# 0            7.4              0.70         0.00
# 1            7.8              0.88         0.00
# 2            7.8              0.76         0.04
# 3           11.2              0.28         0.56
# 4            7.4              0.70         0.00

# %%
#Pickling- all pandas objects with to_pickle methods which use python's cPickel module to save data structures to disk using the pickle format.
df.to_pickle('df_excel')

# %%
df=pd.read_pickle("df_excel")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fixed acidity     1599 non-null   float64
#  1   volatile acidity  1599 non-null   float64
#  2   citric acid       1599 non-null   float64
# dtypes: float64(3)
# memory usage: 37.6 KB

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df["volatile acidity"].value_counts()
# Out:
# 0.600    47
# 0.500    46
# 0.430    43
# 0.590    39
# 0.360    38
#          ..
# 1.090     1
# 1.035     1
# 1.580     1
# 0.950     1
# 0.805     1
# Name: volatile acidity, Length: 143, dtype: int64

# %%
df.describe() #the categorical feature will be skipped.
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df[df["citric acid"]> 0.5]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 16              8.5              0.28         0.56             1.8      0.092
# 19              7.9              0.32         0.51             1.8      0.341
# 47              8.7              0.29         0.52             1.6      0.113
# 56             10.2              0.42         0.57             3.4      0.070
# ...             ...               ...          ...             ...        ...
# 1508            7.1              0.27         0.60             2.1      0.074
# 1566            6.7              0.16         0.64             2.1      0.059
# 1570            6.4              0.36         0.53             2.2      0.230
# 1574            5.6              0.31         0.78            13.9      0.074
# 1576            8.0              0.30         0.63             1.6      0.081
#
# ...

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
# quality                    0.124052         -0.390558     0.226373
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
df.dtypes
# Out:
# fixed acidity       float64
# volatile acidity    float64
# citric acid         float64
# dtype: object
